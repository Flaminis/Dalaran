# %%
from __future__ import annotations

from dalaran.notebook import Viewer

v = Viewer(
    width="auto",
    height="auto",
    url="https://app.dalaran.dev/version/nightly/examples/raw_mesh.dlr",
)
v.update_panels(
    blueprint="hidden",
    selection="hidden",
    time="collapsed",
)
